# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\msi1\Videos\Gradio\Data\SoftMoc_Womens.csv', encoding='latin1')  # or encoding='cp1252'

# %%
df.to_csv(r'C:\Users\msi1\Videos\Gradio\Data\SoftMoc_Womens.csv', index=False, encoding='utf-8')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import re

# Load your CSV
df = pd.read_csv(r'C:\Users\msi1\Videos\ShoeLlama\Data\armour_shoes_women.csv')

# %%
# Let's say the column name is 'Product'
# Strip leading/trailing whitespace and replace multiple spaces with a single space
#df['name'] = df['name'].apply(lambda x: re.sub(r'\s+', ' ', str(x)).strip())
#df['description'] = df['description'].apply(lambda x: re.sub(r'\s+', ' ', str(x)).strip())
#df.drop('Item_ID', axis=1, inplace=True)
df['price'] = 'Price- $' + df['price'].astype(str)
df['new_description'] = df['description'].astype(str) + ', ' + df['price'].astype(str)
df.drop(['price', 'description'], axis=1, inplace=True)
df = df.sort_values(by='name', ascending=True)


# Optionally, save the cleaned CSV
df.to_csv(r'C:\Users\msi1\Videos\ShoeLlama\Data\armour_shoes_women_cleaned.csv', index=False)
